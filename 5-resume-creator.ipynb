# %% [markdown]
# ---
# format:
#     html:
#         embed-resources: true
# ---

# %% [markdown]
# # Resume and cover letter creator
#
# Using a combination of an LLM API wrapper and Quarto, write a pipeline that will create a resume PDF (or HTML), and a cover letter, for each of the given job descriptions.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## API

# %%
import google.generativeai as genai

# %%
import json
with open('C:/Users/admin/.google-api.json') as f:
    keys = json.load(f)

# %%
API_KEY = keys['googleapi']

# %%
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel("gemini-1.5-flash")

# %% [markdown]
# ### Define the Input Data

# %%
df = pd.read_csv("df_cleaned.csv")

# %% [markdown]
# ## Use LLM for Content Generation

# %% [markdown]
# ### Prompt Engineering for Resume Content

# %%
import json
from pprint import pprint

# Initialize the generative model
model = genai.GenerativeModel("gemini-1.5-flash")

# Define placeholder profile for Jane Doe
jane_doe_profile = {
    "Name": "Jane Doe",
    "Contact Information": {
        "Email": "jane.doe@example.com",
        "Phone": "(123) 456-7890",
        "Location": "New York, NY",
        "LinkedIn": "linkedin.com/in/jane-doe",
        "Portfolio": "janedoe-portfolio.com"
    },
    "Professional Summary": "Data Analyst with 3+ years of experience in data analysis, visualization, and machine learning. Skilled in SQL, Python, and data visualization tools, with a strong focus on delivering actionable insights.",
    "Education": {
        "Degree": "Bachelor of Science in Computer Science",
        "University": "University of Example",
        "Location": "New York, NY",
        "Graduation Date": "May 2018",
        "Relevant Courses": ["Data Structures", "Algorithms", "Machine Learning", "Database Systems"]
    },
    "Work Experience": [
        {
            "Title": "Data Analyst",
            "Company": "Example Corp",
            "Location": "New York, NY",
            "Date": "July 2018 – Present",
            "Responsibilities": [
                "Conducted data analysis and visualization to support business decision-making.",
                "Developed SQL queries to retrieve data for analysis and reporting.",
                "Collaborated with cross-functional teams to deliver insights on customer behavior, market trends, and operational efficiency."
            ],
            "Tools Used": ["SQL", "Python", "Tableau"]
        },
        {
            "Title": "Intern - Data Science",
            "Company": "Example Inc.",
            "Location": "New York, NY",
            "Date": "May 2017 – August 2017",
            "Responsibilities": [
                "Assisted in data cleaning, feature engineering, and predictive modeling.",
                "Presented insights to senior management, improving model accuracy by 15%."
            ],
            "Tools Used": ["Python", "R", "Excel"]
        }
    ],
    "Skills": {
        "Technical": ["Python", "SQL", "R", "Tableau", "Machine Learning", "Data Analysis", "Data Visualization"],
        "Soft": ["Communication", "Problem Solving", "Team Collaboration", "Adaptability", "Critical Thinking"]
    },
    "Certifications": [
        "Google Data Analytics Professional Certificate",
        "Microsoft Certified: Azure Data Scientist Associate"
    ],
    "Projects": [
        {
            "Name": "Customer Segmentation Analysis",
            "Description": "Created customer segments using clustering algorithms for targeted marketing campaigns."
        },
        {
            "Name": "Sales Forecasting Model",
            "Description": "Developed a forecasting model to predict sales trends, reducing inventory costs by 10%."
        }
    ],
    "Languages": ["English (Fluent)", "Spanish (Conversational)"],
    "Interests": ["Data Ethics", "AI for Social Good", "Tech Blogging"]
}

# Function to generate resume content based on prompts
def generate_resume_content(profile, content_type):
    """
    Generate specific resume content based on Jane Doe's profile using Gemini API.
    
    Parameters:
    profile (dict): The Jane Doe profile data.
    content_type (str): The type of content to generate ("summary", "skills", "experience", or "education").
    
    Returns:
    str: Generated content as text.
    """
    # Define prompts for different resume sections
    prompts = {
        "summary": f"Create a professional summary based on Jane Doe's profile: {profile['Professional Summary']}.",
        "skills": f"List the relevant skills for Jane Doe based on her technical and soft skills: {profile['Skills']}.",
        "experience": f"Describe Jane Doe's relevant experience for a data analyst role, focusing on the experience sections: {profile['Work Experience']}.",
        "education": f"Provide a brief educational background for Jane Doe, focusing on her degree and relevant courses: {profile['Education']}."
    }
    
    # Generate content using the specified prompt
    response = model.generate_content(prompts[content_type])
    return response.text.strip()

# Generate and store the resume content based on Jane Doe's profile
resume_content = {
    "Summary": generate_resume_content(jane_doe_profile, "summary"),
    "Skills": generate_resume_content(jane_doe_profile, "skills"),
    "Experience": generate_resume_content(jane_doe_profile, "experience"),
    "Education": generate_resume_content(jane_doe_profile, "education")
}

# Save generated resume content to JSON file for later use
with open("jane_doe_generated_resume.json", "w") as f:
    json.dump(resume_content, f, indent=4)

# Display the generated resume content for verification
pprint(resume_content)
# Out:
# {'Education': 'Jane Doe holds a Bachelor of Science in Computer Science from '
#               'the University of Example in New York, NY, graduating in May '
#               '2018. Her coursework focused on core computer science '
#               'principles, including Data Structures, Algorithms, Machine '
#               'Learning, and Database Systems. This foundation provides her '
#               'with a strong understanding of computational theory and '
#               'practical skills for working with data and developing software '
#               'applications.',
#  'Experience': "## Jane Doe's Relevant Experience for a Data Analyst Role\n"
#                '\n'
#                'Jane Doe boasts a strong background in data analysis, '
#                'demonstrated through her experience at both **Example Corp** '
#                'and **Example Inc**. \n'
#                '\n'
#                '**At Example Corp, as a Data Analyst (July 2018 – Present):**\n'
#                '\n'
#                '* Jane has honed her skills in analyzing and visualizing data '
#                'to inform business decisions. \n'
#                '* She has extensive experience in SQL, using it to retrieve '
#                'data for analysis and reporting, highlighting her proficiency '
#                'in querying and extracting relevant information.\n'
#                '* Jane effectively collaborates with cross-functional teams, '
#                'offering valuable insights into customer behavior, market '
#                'trends, and operational efficiency. \n'
#                '* Her expertise in data visualization tools like Tableau '
#                'demonstrates her ability to communicate complex data in a '
#                'clear and concise manner.\n'
#                '\n'
#                '**During her internship at Example Inc. (May 2017 – August '
#                '2017) as an Intern - Data Science:**\n'
#                '\n'
#                '* Jane gained experience in data cleaning, feature '
#                'engineering, and predictive modeling, further solidifying her '
#                'understanding of data manipulation and analysis.\n'
#                '* Her ability to present insightful findings to senior '
#                'management, resulting in a 15% improvement in model accuracy, '
#                'showcases her strong analytical and communication skills. \n'
#                '* The internship provided Jane with exposure to various '
#                'programming languages like Python, R, and Excel, demonstrating '
#                'her adaptability and willingness to learn new tools.\n'
#                '\n'
#                "Overall, Jane's experience showcases her strong analytical "
#                'abilities, proficiency in SQL and other data analysis tools, '
#                'collaborative spirit, and ability to effectively communicate '
#                'data-driven insights. She is well-equipped to excel in a data '
#                'analyst role, bringing valuable experience and a demonstrated '
#                'commitment to delivering impactful results.',
#  'Skills': '## Relevant Skills for Jane Doe:\n'
#            '\n'
#            '**Technical Skills:**\n'
#            '\n'
#            '* **Programming:** Python, R, SQL\n'
#            '* **Data Analysis:** Data Analysis, Machine Learning\n'
#            '* **Data Visualization:** Tableau\n'
#            '* **Database Management:** SQL\n'
#            '\n'
#            '**Soft Skills:**\n'
#            '\n'
#            '* **Communication:**  Effective communication is crucial for '
#            'collaborating with colleagues, presenting findings, and explaining '
#            'technical concepts to non-technical audiences.\n'
#            "* **Problem Solving:**  Jane Doe's ability to solve complex "
#            'problems is essential for identifying patterns in data, diagnosing '
#            'issues, and developing effective solutions.\n'
#            '* **Team Collaboration:** Her teamwork skills are vital for '
#            'working effectively with others on data projects and collaborating '
#            'on solutions. \n'
#            "* **Adaptability:** Jane Doe's adaptability allows her to learn "
#            'new technologies and approaches quickly, and adjust to changing '
#            'project requirements.\n'
#            '* **Critical Thinking:** Her ability to analyze information '
#            'critically, evaluate data, and draw insightful conclusions is '
#            'essential for data-driven decision making.\n'
#            '\n'
#            '**Combined Skills:**\n'
#            '\n'
#            "* **Data Scientist:** This role combines Jane Doe's technical "
#            'skills in programming, data analysis, and visualization, with her '
#            'soft skills in problem solving and critical thinking.\n'
#            "* **Data Analyst:** Jane Doe's expertise in data analysis, "
#            'visualization, and communication makes her suitable for this '
#            'role.\n'
#            '* **Machine Learning Engineer:** Her knowledge of Python, Machine '
#            'Learning, and data analysis positions her well for this role.\n'
#            '* **Business Intelligence Analyst:** Her combination of technical '
#            'and soft skills could be applied to this role, where she can '
#            'analyze data to inform business decisions.\n'
#            '\n'
#            '**Other Potential Skills:**\n'
#            '\n'
#            "Depending on Jane Doe's specific interests and experience, she may "
#            'also possess additional skills such as:\n'
#            '\n'
#            '* **Statistical Modeling:**  Experience with statistical modeling '
#            'techniques would enhance her data analysis capabilities.\n'
#            '* **Project Management:**  Project management skills would be '
#            'valuable for leading and coordinating data projects.\n'
#            '* **Cloud Computing:**  Experience with cloud computing platforms '
#            'like AWS or Azure would be an asset.\n'
#            '\n'
#            "Overall, Jane Doe's diverse skillset positions her well for "
#            'various roles within the data science and analytics fields.',
#  'Summary': 'Data-driven professional with 3+ years of experience in '
#             'extracting, analyzing, and visualizing data to generate '
#             'actionable insights. Proficient in SQL, Python, and data '
#             'visualization tools to translate complex datasets into meaningful '
#             'stories. Proven ability to identify trends, patterns, and '
#             'opportunities for optimization, ultimately supporting informed '
#             'decision-making.'}

# %% [markdown]
# ### Prompt Engineering for Cover Letter

# %%
# Initialize the generative model
model = genai.GenerativeModel("gemini-1.5-flash")

# Load the first 10 rows from CSV
df = pd.read_csv("df_cleaned.csv").head(10)

# Define placeholder profile for Jane Doe
jane_doe_profile = {
    "Name": "Jane Doe",
    "Contact Information": {
        "Email": "jane.doe@example.com",
        "Phone": "(123) 456-7890",
        "Location": "New York, NY"
    },
    "Work Experience": [
        {
            "Title": "Data Analyst",
            "Company": "Example Corp",
            "Responsibilities": [
                "Conducted data analysis and visualization to support business decision-making.",
                "Developed SQL queries to retrieve data for analysis and reporting.",
                "Collaborated with cross-functional teams to deliver insights on customer behavior, market trends, and operational efficiency."
            ]
        }
    ],
    "Skills": {
        "Technical": ["Python", "SQL", "R", "Tableau", "Machine Learning", "Data Analysis"],
        "Soft": ["Communication", "Problem Solving", "Team Collaboration", "Adaptability", "Critical Thinking"]
    }
}

# Function to construct a cover letter prompt based on job description
def construct_cover_letter_prompt(row, profile):
    """
    Construct a cover letter prompt using job description details and Jane Doe's profile.
    
    Parameters:
    row (pd.Series): A row from the dataframe representing a job description.
    profile (dict): The Jane Doe profile data.
    
    Returns:
    str: A formatted prompt for generating a cover letter.
    """
    prompt = (
        f"Write a cover letter for {profile['Name']} applying for the role of {row['title']} at {row['company_name']}.\n"
        f"Include an introduction mentioning her interest in the position, her relevant experience as described below, "
        f"and her skills that match the job requirements.\n"
        f"{profile['Name']}'s contact details are:\n"
        f"Email: {profile['Contact Information']['Email']}, Phone: {profile['Contact Information']['Phone']}, Location: {profile['Contact Information']['Location']}.\n"
        f"The job was advertised on {row['via']}.\n"
        f"Relevant experience:\n"
        f"{profile['Work Experience'][0]['Responsibilities']}.\n"
        f"Her key skills are: {', '.join(profile['Skills']['Technical'] + profile['Skills']['Soft'])}.\n"
        f"Conclude with a polite closing statement expressing appreciation and a desire for an interview opportunity."
    )
    return prompt

# Dictionary to store generated cover letters
cover_letters = {}

# Generate cover letters for the first 10 job descriptions
for idx, row in df.iterrows():
    # Construct prompt for each job
    prompt = construct_cover_letter_prompt(row, jane_doe_profile)
    
    # Generate cover letter content using the Gemini model
    response = model.generate_content(prompt)
    cover_letters[f"Job_{idx+1}"] = response.text.strip()

# Save generated cover letters to a JSON file for later use
with open("jane_doe_cover_letters.json", "w") as f:
    json.dump(cover_letters, f, indent=4)

# Print generated cover letters for verification
pprint(cover_letters)
# Out:
# {'Job_1': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Photon\n'
#           '[Company Address]\n'
#           '\n'
#           '**Subject: Application for AI Solution Architect - Azure**\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my enthusiastic interest in the AI Solution '
#           'Architect - Azure position at Photon, as advertised on Indeed. With '
#           'my proven experience in data analysis, data visualization, and AI '
#           'technologies, I am confident in my ability to contribute '
#           'significantly to your team.\n'
#           '\n'
#           'Throughout my career, I have consistently demonstrated my expertise '
#           'in leveraging data to drive impactful business decisions. My '
#           'experience includes:\n'
#           '\n'
#           '* **Conducted data analysis and visualization** to support business '
#           'decision-making, resulting in [quantifiable result, e.g., a 15% '
#           'increase in customer retention].\n'
#           '* **Developed SQL queries** to retrieve data for analysis and '
#           'reporting, enabling me to identify key trends and patterns.\n'
#           '* **Collaborated with cross-functional teams** to deliver insights '
#           'on customer behavior, market trends, and operational efficiency, '
#           'leading to [quantifiable result, e.g., optimized marketing '
#           'campaigns with a 20% higher ROI].\n'
#           '\n'
#           'My technical skills align perfectly with the requirements of this '
#           'role, including proficiency in Python, SQL, R, Tableau, and Machine '
#           'Learning. I am also a strong communicator, problem solver, and team '
#           'player, with a proven ability to adapt to new technologies and '
#           'challenges.\n'
#           '\n'
#           'I am eager to leverage my experience and skills to contribute to '
#           "Photon's success and help your organization achieve its goals. I am "
#           'confident that I possess the necessary qualifications and '
#           'dedication to excel in this role.\n'
#           '\n'
#           'Thank you for your time and consideration. I look forward to the '
#           'opportunity to discuss my qualifications further in an interview.\n'
#           '\n'
#           'Sincerely,\n'
#           '\n'
#           'Jane Doe',
#  'Job_10': '[Your Name]\n'
#            '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#            '\n'
#            '[Date]\n'
#            '\n'
#            'Hiring Manager\n'
#            'C3.ai\n'
#            '[Company Address]\n'
#            '\n'
#            '**Subject: Application for AI Solution Architect / Senior AI '
#            'Solution Architect (Pre-Sales) - [Job ID from Indeed]**\n'
#            '\n'
#            'Dear Hiring Manager,\n'
#            '\n'
#            'I am writing to express my strong interest in the AI Solution '
#            'Architect / Senior AI Solution Architect (Pre-Sales) position at '
#            'C3.ai, as advertised on Indeed. With my proven experience in data '
#            'analysis, machine learning, and communication, I am confident that '
#            'I possess the necessary skills and expertise to excel in this role '
#            'and contribute significantly to your team.\n'
#            '\n'
#            'In my previous roles, I have demonstrated a strong track record of '
#            'success in:\n'
#            '\n'
#            '* **Conducted data analysis and visualization** to support '
#            'business decision-making, leveraging my proficiency in Python, '
#            'SQL, R, and Tableau.\n'
#            '* **Developed SQL queries** to retrieve data for analysis and '
#            'reporting, providing actionable insights to stakeholders.\n'
#            '* **Collaborated effectively with cross-functional teams** to '
#            'deliver insightful reports on customer behavior, market trends, '
#            'and operational efficiency.\n'
#            '\n'
#            'My key skills, including Python, SQL, R, Tableau, Machine '
#            'Learning, Data Analysis, Communication, Problem Solving, Team '
#            'Collaboration, Adaptability, and Critical Thinking, align '
#            'perfectly with the requirements outlined in the job description. I '
#            'am particularly excited about the opportunity to leverage my '
#            'technical expertise and analytical capabilities to develop '
#            'innovative AI solutions that drive business value.\n'
#            '\n'
#            "I am eager to learn more about C3.ai's mission and how I can "
#            "contribute to your team's success. I am available for an interview "
#            'at your earliest convenience and can be reached at [Your Phone '
#            'Number] or [Your Email Address].\n'
#            '\n'
#            'Thank you for your time and consideration.\n'
#            '\n'
#            'Sincerely,\n'
#            '\n'
#            'Jane Doe',
#  'Job_2': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Deloitte\n'
#           '[Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my keen interest in the AI Solution '
#           'Architect position advertised on Deloitte Jobs. With my strong '
#           'background in data analysis, machine learning, and proven '
#           'experience in collaborating with cross-functional teams, I am '
#           'confident in my ability to excel in this role and contribute '
#           "significantly to Deloitte's AI initiatives.\n"
#           '\n'
#           'Throughout my career, I have consistently demonstrated a passion '
#           'for leveraging data and technology to drive meaningful business '
#           'outcomes. My expertise in data analysis has allowed me to:\n'
#           '\n'
#           '* **Conducted data analysis and visualization to support business '
#           'decision-making.**\n'
#           '* **Developed SQL queries to retrieve data for analysis and '
#           'reporting.**\n'
#           '* **Collaborated with cross-functional teams to deliver insights on '
#           'customer behavior, market trends, and operational efficiency.**\n'
#           '\n'
#           'My skillset, including proficiency in Python, SQL, R, Tableau, '
#           'Machine Learning, and Data Analysis, coupled with my strong '
#           'communication, problem-solving, and team collaboration abilities, '
#           'make me a highly adaptable and critical thinker. I am eager to '
#           'leverage my knowledge and expertise to architect and implement '
#           'innovative AI solutions that deliver tangible business value.\n'
#           '\n'
#           'I am confident that my skills and experience align perfectly with '
#           'the requirements of this position and I am eager to learn more '
#           "about how I can contribute to Deloitte's success. Thank you for "
#           'your time and consideration. I look forward to the opportunity to '
#           'discuss my qualifications further in an interview.\n'
#           '\n'
#           'Sincerely,\n'
#           'Jane Doe',
#  'Job_3': '[Your Name]\n'
#           '[Your Address]\n'
#           '[Your Phone Number]\n'
#           '[Your Email Address]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Microsoft\n'
#           '[Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my enthusiastic interest in the Solution '
#           'Architect Data & AI - CTJ - Secret position at Microsoft, as '
#           'advertised on LinkedIn. With my strong background in data analysis, '
#           'machine learning, and collaboration, I am confident I possess the '
#           'skills and experience necessary to excel in this role.\n'
#           '\n'
#           'Throughout my career, I have honed my abilities in conducting '
#           'comprehensive data analysis and visualization, leveraging SQL to '
#           'retrieve data for insightful reporting, and collaborating '
#           'effectively with cross-functional teams to deliver impactful '
#           'insights on customer behavior, market trends, and operational '
#           'efficiency. \n'
#           '\n'
#           'My proficiency in Python, SQL, R, Tableau, and machine learning '
#           'techniques, coupled with my strong communication, problem-solving, '
#           'and team collaboration skills, allows me to translate complex data '
#           'into actionable insights that drive strategic decisions. I am a '
#           'highly adaptable and critical thinker, consistently seeking '
#           'innovative solutions to complex challenges.\n'
#           '\n'
#           "I am eager to contribute my expertise to Microsoft's data and AI "
#           'initiatives and contribute to the development of innovative '
#           'solutions that enhance business operations and customer '
#           'experiences. \n'
#           '\n'
#           'Thank you for considering my application. I am available for an '
#           'interview at your earliest convenience and welcome the opportunity '
#           'to discuss how my skills and experience align with your '
#           'requirements.\n'
#           '\n'
#           'Sincerely,\n'
#           'Jane Doe',
#  'Job_4': '[Your Name]\n'
#           '[Your Address]\n'
#           '[Your Phone Number]\n'
#           '[Your Email Address]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           '[Hiring Manager Name]\n'
#           '[Hiring Manager Title]\n'
#           'Vorto\n'
#           '[Vorto Address]\n'
#           '\n'
#           'Dear [Hiring Manager Name],\n'
#           '\n'
#           'I am writing to express my strong interest in the AI Solutions '
#           'Architect position at Vorto, which I saw advertised on JobServe. '
#           'With my extensive experience in data analysis, machine learning, '
#           'and collaborative environments, I am confident that I possess the '
#           'skills and qualifications necessary to excel in this role.\n'
#           '\n'
#           'Throughout my career, I have consistently applied my expertise in '
#           'Python, SQL, R, and Tableau to conduct data analysis and '
#           'visualization, supporting business decision-making. I have '
#           'developed SQL queries to retrieve data for analysis and reporting, '
#           'and collaborated effectively with cross-functional teams to deliver '
#           'actionable insights on customer behavior, market trends, and '
#           'operational efficiency. \n'
#           '\n'
#           'My key skills, including Machine Learning, Data Analysis, '
#           'Communication, Problem Solving, Team Collaboration, Adaptability, '
#           'and Critical Thinking, align perfectly with the requirements '
#           'outlined in the job description. I am passionate about leveraging '
#           'AI to solve complex business problems and am eager to contribute my '
#           'technical and analytical abilities to the success of Vorto.\n'
#           '\n'
#           'I am highly motivated and possess a strong work ethic, coupled with '
#           'a genuine desire to learn and grow within a dynamic and innovative '
#           'company. I am confident that my skills and experience would be a '
#           'valuable asset to your team.\n'
#           '\n'
#           'Thank you for your time and consideration. I am eager to learn more '
#           'about this opportunity and would welcome the chance to discuss my '
#           'qualifications in an interview.\n'
#           '\n'
#           'Sincerely,\n'
#           '\n'
#           'Jane Doe',
#  'Job_5': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Google Cloud\n'
#           '[Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my strong interest in the Solutions '
#           'Architect, Data and AI position at Google Cloud, as advertised on '
#           'Taro. With my proven experience in data analysis, machine learning, '
#           'and cloud technologies, I am confident that I possess the skills '
#           'and passion to thrive in this role and contribute to Google’s '
#           'mission of empowering organizations with transformative data '
#           'solutions.\n'
#           '\n'
#           'Throughout my career, I have gained extensive experience in '
#           '[mention relevant experience points like: conducting data analysis '
#           'and visualization, developing SQL queries, collaborating with '
#           'cross-functional teams, delivering insights on customer behavior, '
#           'market trends, and operational efficiency]. My expertise spans a '
#           'range of technologies, including Python, SQL, R, Tableau, and '
#           'Machine Learning, which align perfectly with the requirements '
#           'outlined in the job description.\n'
#           '\n'
#           'Furthermore, my exceptional communication and problem-solving '
#           'skills enable me to effectively collaborate with clients and '
#           'internal teams, translating complex technical concepts into '
#           'actionable insights. I am a highly adaptable and critical thinker, '
#           'always eager to learn and contribute to a dynamic and innovative '
#           'environment.\n'
#           '\n'
#           'I am enthusiastic about the opportunity to leverage my skills and '
#           'experience at Google Cloud, where I can contribute to the '
#           'development and implementation of cutting-edge data solutions. I am '
#           'confident that I can make a significant impact and contribute to '
#           "Google's continued success.\n"
#           '\n'
#           'Thank you for your time and consideration. I look forward to the '
#           'opportunity to discuss my qualifications further in an interview.\n'
#           '\n'
#           'Sincerely,\n'
#           '\n'
#           'Jane Doe',
#  'Job_6': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email] \n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Microsoft\n'
#           '[Microsoft Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my strong interest in the Cloud Solution '
#           'Architect - Data & AI position advertised on LinkedIn.  As a highly '
#           'skilled data professional with a proven track record of success in '
#           'data analysis, visualization, and machine learning, I believe my '
#           'skills and experience align perfectly with the requirements of this '
#           'role.\n'
#           '\n'
#           'Throughout my career, I have consistently demonstrated my ability '
#           'to leverage data to drive business impact. I have conducted data '
#           'analysis and visualization to support critical business decisions, '
#           'developed robust SQL queries for data retrieval and reporting, and '
#           'collaborated with cross-functional teams to deliver valuable '
#           'insights on customer behavior, market trends, and operational '
#           'efficiency. \n'
#           '\n'
#           'My expertise in Python, SQL, R, Tableau, and machine learning '
#           'enables me to build and implement data-driven solutions that '
#           'enhance business performance. I am also a strong communicator, '
#           'problem solver, and team player, adept at collaborating effectively '
#           'across diverse teams and adapting to new challenges. \n'
#           '\n'
#           'I am particularly excited about the opportunity to contribute to '
#           "Microsoft's cutting-edge data and AI initiatives. My passion for "
#           'data-driven solutions, coupled with my technical skills and '
#           'collaborative nature, makes me confident in my ability to excel in '
#           'this role and make a significant contribution to your team.\n'
#           '\n'
#           'Thank you for your time and consideration. I welcome the '
#           'opportunity to discuss my qualifications further and demonstrate '
#           'how my expertise can benefit Microsoft.\n'
#           '\n'
#           'Sincerely,\n'
#           'Jane Doe',
#  'Job_7': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Roehl Transport\n'
#           '[Company Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my strong interest in the AI Solution '
#           'Architect position advertised on Indeed. With my extensive '
#           'experience in data analysis, machine learning, and collaborating '
#           'with cross-functional teams, I am confident I possess the skills '
#           'and knowledge to excel in this role and contribute significantly to '
#           "Roehl Transport's success.\n"
#           '\n'
#           'In my previous role, I successfully conducted data analysis and '
#           'visualization to support business decision-making, developed SQL '
#           'queries for data retrieval and reporting, and collaborated with '
#           'teams to deliver insights on customer behavior, market trends, and '
#           'operational efficiency. My expertise in Python, SQL, R, Tableau, '
#           'and machine learning, combined with my strong communication and '
#           'problem-solving skills, enables me to effectively translate data '
#           'into actionable solutions.\n'
#           '\n'
#           "I am particularly drawn to Roehl Transport's commitment to "
#           'innovation and leveraging technology to enhance its operations. I '
#           'am eager to contribute my skills and passion for AI to drive '
#           'improvements in areas such as route optimization, predictive '
#           'maintenance, and customer experience.\n'
#           '\n'
#           'Thank you for your time and consideration. I am available for an '
#           'interview at your earliest convenience and welcome the opportunity '
#           'to discuss how my qualifications can benefit Roehl Transport.\n'
#           '\n'
#           'Sincerely,\n'
#           '\n'
#           'Jane Doe',
#  'Job_8': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#           '[Date]\n'
#           '\n'
#           'Kizan Technologies\n'
#           '[Company Address]\n'
#           '\n'
#           '**Subject: Application for Data and AI Solutions Architect - '
#           'Remote**\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my strong interest in the Data and AI '
#           'Solutions Architect position advertised on Recruit.net. With my '
#           'extensive experience in data analysis, machine learning, and cloud '
#           'technologies, I am confident in my ability to contribute '
#           "significantly to Kizan Technologies' success.\n"
#           '\n'
#           'Throughout my career, I have consistently demonstrated my ability '
#           'to effectively translate complex data into actionable insights. I '
#           'have:\n'
#           '\n'
#           '* **Conducted data analysis and visualization** to support business '
#           'decision-making, providing clear and compelling presentations to '
#           'stakeholders.\n'
#           '* **Developed SQL queries** to retrieve data for analysis and '
#           'reporting, ensuring data accuracy and integrity.\n'
#           '* **Collaborated with cross-functional teams** to deliver insights '
#           'on customer behavior, market trends, and operational efficiency, '
#           'fostering collaboration and communication.\n'
#           '\n'
#           'My technical skills are well-aligned with the requirements of this '
#           'role. I am proficient in **Python, SQL, R, Tableau, and Machine '
#           'Learning**, and I have a strong understanding of data warehousing, '
#           'data mining, and predictive analytics. I am also an effective '
#           'communicator, problem-solver, and team player, with a proven '
#           'ability to adapt to new technologies and challenges.\n'
#           '\n'
#           'I am eager to learn more about this opportunity and how my skills '
#           "and experience can contribute to Kizan Technologies' mission. I am "
#           'available for an interview at your earliest convenience. \n'
#           '\n'
#           'Thank you for your time and consideration.\n'
#           '\n'
#           'Sincerely,\n'
#           'Jane Doe',
#  'Job_9': '[Your Name]\n'
#           '[Your Address] | [Your Phone Number] | [Your Email Address]\n'
#           '\n'
#           '[Date]\n'
#           '\n'
#           'Hiring Manager\n'
#           'Lionbridge\n'
#           '[Company Address]\n'
#           '\n'
#           'Dear Hiring Manager,\n'
#           '\n'
#           'I am writing to express my strong interest in the Solutions '
#           'Architect, AI position at Lionbridge, as advertised on Lensa.  With '
#           'my extensive experience in data analysis, machine learning, and '
#           'collaborative project delivery, I am confident I possess the skills '
#           'and drive to excel in this role.\n'
#           '\n'
#           'Throughout my career, I have honed my expertise in leveraging data '
#           'to drive strategic decision-making. I have successfully:\n'
#           '\n'
#           '* **Conducted data analysis and visualization** to identify key '
#           'trends and insights, leading to improved business outcomes.\n'
#           '* **Developed SQL queries** to extract and manipulate data for '
#           'analysis and reporting, ensuring data accuracy and efficiency.\n'
#           '* **Collaborated with cross-functional teams** to deliver impactful '
#           'insights on customer behavior, market trends, and operational '
#           'efficiency.\n'
#           '\n'
#           'My technical skillset includes proficiency in Python, SQL, R, and '
#           'Tableau, which are essential for building and implementing '
#           'AI-driven solutions. I am also well-versed in machine learning '
#           'techniques, enabling me to effectively analyze complex datasets and '
#           'develop predictive models.\n'
#           '\n'
#           'Furthermore, I am a highly communicative and collaborative '
#           'individual with strong problem-solving and critical thinking '
#           'abilities. My adaptability and commitment to continuous learning '
#           'ensure I can effectively navigate the ever-evolving landscape of AI '
#           'technologies.\n'
#           '\n'
#           "I am eager to contribute my skills and passion to Lionbridge's "
#           "innovative team and contribute to the company's success. Thank you "
#           'for your time and consideration. I look forward to discussing my '
#           'qualifications further in an interview.\n'
#           '\n'
#           'Sincerely,\n'
#           '\n'
#           'Jane Doe'}

# %% [markdown]
# ## Organize and Structure Content in Quarto

# %%
import json

# Load generated content from JSON files
with open("jane_doe_generated_resume.json") as resume_file:
    resume_data = json.load(resume_file)

with open("jane_doe_cover_letters.json") as cover_letter_file:
    cover_letter_data = json.load(cover_letter_file)

# Define a function to populate the Quarto template with data
def populate_template(template_path, output_path, data):
    with open(template_path, "r") as file:
        template = file.read()

    # Ensure Skills is structured correctly
    if isinstance(data.get("Skills"), dict):
        skills_technical = ", ".join(data["Skills"].get("Technical", []))
        skills_soft = ", ".join(data["Skills"].get("Soft", []))
    else:
        skills_technical = ""
        skills_soft = ""

    # Replace placeholders in the template with actual data
    filled_content = template.replace("{{summary}}", data.get("Summary", ""))
    filled_content = filled_content.replace("{{skills_technical}}", skills_technical)
    filled_content = filled_content.replace("{{skills_soft}}", skills_soft)
    filled_content = filled_content.replace("{{experience}}", data.get("Experience", ""))
    filled_content = filled_content.replace("{{education}}", data.get("Education", ""))
    filled_content = filled_content.replace("{{cover_letter}}", cover_letter_data.get("Job_1", ""))  # Example using the first job's cover letter

    # Write the filled content to the output file
    with open(output_path, "w") as output_file:
        output_file.write(filled_content)

# Populate the template
populate_template("jane_doe_resume.qmd", "filled_jane_doe_resume.qmd", resume_data)

# %%
import subprocess

# Run the Quarto render command to generate a PDF
subprocess.run(["quarto", "render", "filled_jane_doe_resume.qmd", "--to", "pdf"])
# Out:
# CompletedProcess(args=['quarto', 'render', 'filled_jane_doe_resume.qmd', '--to', 'pdf'], returncode=1)
